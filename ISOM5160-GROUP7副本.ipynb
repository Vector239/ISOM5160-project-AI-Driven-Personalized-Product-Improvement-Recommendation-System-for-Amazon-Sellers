# %% [markdown]
# # ISOM5160 Project - Group7
#
# - **Dataset:** amazon_food_reviews.csv
# - **Topic:** AI Driven Personalized Product Improvement Recommendation System for Amazon Sellers
# - **Individual Contribution:**
#
#     | Name          | SID      | Contributions                                                                                                          |
#     |---------------|----------|------------------------------------------------------------------------------------------------------------------------|
#     | CAO, Xi       | 21271664 | 评论文本预处理 + 情感分析 + 评论关键词提取 +数据清洗                                                                                                 |
#     | LI, Heyi      |          | 评论、评分异常值分析 （基于评论情感分析）、 PPT 统筹                                                                                          |
#     | LIAO, Jingyu  | 21262106 | 差评原因分析   （基于评论关键词）                                                                                                     |
#     | LIN, Chuwei   |          | 评分时间趋势分析                                                                                                               |
#     | YE, Chenwei   | 21199517 | 用户评论权重分析                                                                                                               |
#     | ZHANG, Ziyang | 21266920 | 1. Data scraping: additional amazon product info <br/>2. Analyse: Correlation Between Ratings and Product Descriptions |
#
#
#
# ## 0. Install requirements and do initialization
# 1. Install requirements and load 'amazon_food_reviews.csv'
# 2. Scrape product info from *amazon.com*
# 3. Load product info and concat to original dataset

# %%
# Run first to install requirements
# !pip install -r requirements.txt

# Run this to speed up the data scraping process
# !unzip -oq new_data.zip
# Out:
# Requirement already satisfied: requests~=2.32.5 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 1)) (2.32.5)
# Requirement already satisfied: pandas~=2.3.2 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 2)) (2.3.2)
# Requirement already satisfied: bs4~=0.0.2 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 3)) (0.0.2)
# Requirement already satisfied: beautifulsoup4~=4.13.5 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (4.13.5)
# Requirement already satisfied: regex~=2024.9.11 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 5)) (2024.9.11)
# Requirement already satisfied: tqdm~=4.66.5 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 6)) (4.66.5)
# Requirement already satisfied: numpy~=1.26.4 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: scipy~=1.15.3 in /opt/anaconda3/lib/python3.12/site-packages (from -r requirements.txt (line 8)) (1.15.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.32.5->-r requirements.txt (line 1)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.32.5->-r requirements.txt (line 1)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.32.5->-r requirements.txt (line 1)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests~=2.32.5->-r requirements.txt (line 1)) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas~=2.3.2->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas~=2.3.2->-r requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas~=2.3.2->-r requirements.txt (line 2)) (2023.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4~=4.13.5->-r requirements.txt (line 4)) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4~=4.13.5->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas~=2.3.2->-r requirements.txt (line 2)) (1.16.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr

from amazon_new_data_scraping import parallel_scrape_amazon_product_info, load_all_data_as_dataframe, \
    extract_comments_from_product_info

df_amazon_food_reviews = pd.read_csv('amazon_food_reviews.csv',
                                     converters={"Time": lambda x: pd.to_datetime(int(x), unit="s")})

# %%
product_id_list = list(df_amazon_food_reviews.ProductId.unique())
print(f"Total number of products: {len(product_id_list)}")
print("Start scraping data...")
parallel_scrape_amazon_product_info(product_id_list, replace=False)
print("Scraping finished.")
df_amazon_product_info = load_all_data_as_dataframe()
print("Product info loaded.")
df_amazon_product_info
# Out:
# Total number of products: 4322
# Start scraping data...
# Using 10 CPU cores for parallel scraping
# Scraping amazon products: 100%|██████████| 4322/4322 [00:01<00:00, 3633.56it/s]
# Successfully scraped 4322/4322 products
# Scraping finished.
# Loading product info: 100%|██████████| 4322/4322 [00:00<00:00, 8986.83it/s]
# Product info loaded.
#       product_id                                      product_title  \
# 0     B0007GFDP4                  Korean Seaweed 0.17oz5gea-4 Packs
# 1     B000EMEEHE  GIN GINS Original Ginger Chews by The Ginger P...
# 2     B000E671W0  Celestial Seasonings Peppermint Herbal Tea, Ca...
# 3     B000084E76       Kookamunga Krazee Kitty Catnip Bubbles, 5 oz
# 4     B0009TQC90  Golden Dragon - Finest Chrysanthemum Pu Erh Te...
# ...          ...                                                ...
# 3376  B0006VB3WC   Katz-n-Flocken All Life Stages Cat Food - 15 lbs
# 3377  B0001PB99K  Maker's Mark Bourbon Flavored Gourmet Cherries...
# 3378  B000EDDSES  Bob's Red Mill Old Country Style Muesli, 18oz ...
# 3379  B00004RBDW  TERRO T380 Outdoor Reusable Fly Magnet Fly Tra...
# 3380  B000F42EC8  Taylors of Harrogate Earl Grey, 50 Teabags (Pa...
#
#                                byline_info  \
# 0                                Brand: JN
# 1        Visit the The Ginger People Store
# 2     Visit the Celestial Seasonings Store
# 3               Visit the KOOKAMUNGA Store
# 4                     Brand: Golden Dragon
# ...                                    ...
# 3376            Visit the Solid Gold Store
# 3377
# 3378        Visit the Bob's Red Mill Store
# 3379                 Visit the Terro Store
# 3380  Visit the Taylors of Harrogate Store
#
#                                     product_description  \
# 0     Freshness Guaranteed Premium Seaweed Winter Ha...
# 1     Deliciously spicy-sweet chewy ginger candies m...
# 2     Nothing is more soothing than a cup of your fa...
# 3     Make your cats go wild with this fun product. ...
# 4     a specially selected of buds and young leaves ...
# ...                                                 ...
# 3376  Ideal for adult cats and kittens, to maintain ...
# 3377
# 3378  Product Description   Old Country Style Muesli...
# 3379  Flies are an ever-present nuisance around home...
# 3380  Product Description   The elegant fragrance of...
#
#                                                category  \
# 0     [Grocery & Gourmet Food, Pantry Staples, Cooki...
# 1     [Grocery & Gourmet Food, Snacks & Sweets, Cand...
# 2     [Grocery & Gourmet Food, Beverages, Tea, Fruit...
# 3               [Pet Supplies, Cats, Toys, Catnip Toys]
# 4       [Grocery & Gourmet Food, Beverages, Tea, Black]
# ...                                                 ...
# 3376                         [Pet Supplies, Cats, Food]
# 3377  [Grocery & Gourmet Food, Pantry Staples, Canne...
# 3378  [Grocery & Gourmet Food, Breakfast Cereal, Mue...
# 3379        [Patio, Lawn & Garden, Pest Control, Traps]
# 3380    [Grocery & Gourmet Food, Beverages, Tea, Black]
#
#                                              alt_images  \
# 0     [https://m.media-amazon.com/images/I/51uDkERYg...
# 1     [https://m.media-amazon.com/images/I/41KQy5H4V...
# 2     [https://m.media-amazon.com/images/I/61iWD7RnS...
# 3     [https://m.media-amazon.com/images/I/4124SxrG1...
# 4     [https://m.media-amazon.com/images/I/51hGQNcQz...
# ...                                                 ...
# 3376  [https://m.media-amazon.com/images/I/517dkgAGm...
# 3377  [https://m.media-amazon.com/images/I/31CDQM754...
# 3378  [https://m.media-amazon.com/images/I/411xsw6he...
# 3379  [https://m.media-amazon.com/images/I/41ecsqa4Z...
# 3380  [https://m.media-amazon.com/images/I/41wxP0usj...
#
#                                          product_detail  \
# 0     {'Product Dimensions': '6.1 x 3.35 x 2.3 inche...
# 1     {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 2     {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 3     {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 4     {'Is Discontinued By Manufacturer': 'No', 'Pac...
# ...                                                 ...
# 3376  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 3377  {'Is Discontinued By Manufacturer': 'No', 'UPC...
# 3378  {'Is Discontinued By Manufacturer': 'No', 'Pro...
# 3379                                                 {}
# 3380  {'Is Discontinued By Manufacturer': 'No', 'Pro...
#
#                                   important_information  \
# 0     {'Ingredients': 'Seaweed. non gmo com oil. non...
# 1     {'Safety Information': 'Made in a facility tha...
# 2     {'Safety Information': 'This product is labell...
# 3                                                    {}
# 4     {'Legal Disclaimer': 'Statements regarding die...
# ...                                                 ...
# 3376                                                 {}
# 3377  {'Legal Disclaimer': 'Statements regarding die...
# 3378  {'Ingredients': 'Whole Grain Wheat, Dates, Sun...
# 3379                                                 {}
# 3380  {'Safety Information': 'This product is labell...
#
#                                            top_comments  CountAltImages  \
# 0     [{'date': 'March 22, 2013', 'title': 'Best Tas...               4
# 1     [{'date': 'July 9, 2014', 'title': 'Truly Life...               7
# 2     [{'date': 'August 3, 2025', 'title': 'DELICIOU...               6
# 3     [{'date': 'July 17, 2015', 'title': 'My cat is...               3
# 4     [{'date': 'January 7, 2012', 'title': 'Not exa...               7
# ...                                                 ...             ...
# 3376  [{'date': 'November 25, 2011', 'title': 'Katz-...               5
# 3377                                                 []               1
# 3378  [{'date': 'October 17, 2011', 'title': 'I Love...               7
# 3379  [{'date': 'July 22, 2025', 'title': 'It works!...               7
# 3380  [{'date': 'August 31, 2025', 'title': 'Smooth ...               5
#
#       Score               ScoreDistribution  ScorePolarizationIndex  \
# 0       3.8    [20.0, 0.0, 19.0, 0.0, 61.0]                0.483701
# 1       3.2    [23.0, 9.0, 27.0, 9.0, 32.0]                0.281807
# 2       4.8      [2.0, 1.0, 2.0, 7.0, 88.0]                0.166892
# 3       3.2  [26.0, 12.0, 12.0, 13.0, 37.0]                0.319141
# 4       3.2  [10.0, 20.0, 32.0, 10.0, 28.0]                0.224108
# ...     ...                             ...                     ...
# 3376    4.4     [9.0, 0.0, 14.0, 0.0, 77.0]                0.382746
# 3377    4.0     [0.0, 0.0, 0.0, 100.0, 0.0]                0.000000
# 3378    4.8      [1.0, 1.0, 3.0, 8.0, 87.0]                0.156042
# 3379    4.2     [9.0, 4.0, 9.0, 13.0, 65.0]                0.323871
# 3380    4.5     [4.0, 2.0, 7.0, 13.0, 74.0]                0.260269
#
#       NumRatings  IsFood
# 0              6    True
# 1             62    True
# 2          37825    True
# 3            728   False
# 4             21    True
# ...          ...     ...
# 3376          23    True
# 3377           1    True
# 3378        5058    True
# 3379          -1   False
# 3380       38885    True
#
# [3381 rows x 15 columns]

# %%
# Concat new reviews to the original dataset and drop duplicates
df_amazon_food_reviews = pd.concat([df_amazon_food_reviews, extract_comments_from_product_info(df_amazon_product_info)]
                                   ).drop_duplicates(['Score', 'Time', 'Summary']).reset_index(drop=True)
df_amazon_food_reviews
# Out:
#           Id   ProductId          UserId  \
# 0      350.0  B00067AD4U  A2LYOWC3FC73XK
# 1      439.0  B000G6RYNE   A926YP1BSD72Y
# 2      446.0  B000G6RYNE  A19G8B2QYETD7W
# 3      448.0  B000G6RYNE   ACFPHOYVB71V4
# 4      452.0  B000G6RYNE  A2MUGFV2TDQ47K
# ...      ...         ...             ...
# 29960    NaN  B00004RBDW             NaN
# 29961    NaN  B00004RBDW             NaN
# 29962    NaN  B00004RBDW             NaN
# 29963    NaN  B00004RBDW             NaN
# 29964    NaN  B00004RBDW             NaN
#
#                                  ProfileName  HelpfulnessNumerator  \
# 0      Michael Ekstrum ""expresso bean fan""                     1
# 1                                  Shopper11                     0
# 2                                   NyahNyah                     0
# 3                                      karob                     0
# 4                      Lynrie ""Oh HELL no""                     0
# ...                                      ...                   ...
# 29960                                    NaN                     1
# 29961                                    NaN                     6
# 29962                                    NaN                     0
# 29963                                    NaN                     2
# 29964                                    NaN                     1
#
#        HelpfulnessDenominator  Score       Time  \
# 0                         1.0      5 2007-05-12
# 1                         0.0      5 2011-11-20
# 2                         0.0      3 2011-02-13
# 3                         0.0      5 2010-12-18
# 4                         0.0      3 2010-11-05
# ...                       ...    ...        ...
# 29960                     NaN      4 2025-09-01
# 29961                     NaN      5 2025-08-05
# 29962                     NaN      5 2025-09-08
# 29963                     NaN      3 2025-07-24
# 29964                     NaN      4 2025-08-11
#
#                                                  Summary  \
# 0                    excellent - exactly what I expected
# 1                      Best gluten-free dairy-free chips
# 2                                   Heavy on the Vinegar
# 3                                  BEST BUY in BBQ Chips
# 4                                      An Acquired Taste
# ...                                                  ...
# 29960                                 Awesome fly killer
# 29961  Put this item 40 feet away from any window or ...
# 29962                           Works great; odor is bad
# 29963                  Bait refills not sold separately.
# 29964                                  Great fly trap 👍🏼
#
#                                                     Text
# 0      The product was exactly as advertised and fres...
# 1      These are my favorite gluten-free dairy-free f...
# 2      I usually love Kettle Chips, and love salt & v...
# 3      Tried many varieties of BBQ chips and hands do...
# 4      OK,I did read the reviews which ranged from sp...
# ...                                                  ...
# 29960  This thing works like a charm, it really does ...
# 29961  Very effective help me wipe out 100% of flys i...
# 29962  Hung it up, within a day it had collected so m...
# 29963  The trap works extremely well, and I'm happy w...
# 29964  The media could not be loaded.\n              ...
#
# [29965 rows x 10 columns]

# %% [markdown]
# ## 3.Review weight analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# ========== 0) 输入与准备 ==========
cols = ['ProductId', 'Score', 'HelpfulnessNumerator', 'HelpfulnessDenominator']
reviews = df_amazon_food_reviews[cols].copy()

# 1.1 简单权重：纯 Numerator（给0票一个最小权重，避免全0）
reviews['weight_simple'] = reviews['HelpfulnessNumerator'].fillna(0).clip(lower=0)
reviews.loc[reviews['weight_simple'] == 0, 'weight_simple'] = 1.0

# 1.2 平滑权重：平滑有用率 × 投票强度
a = b = 1.0
r = (reviews['HelpfulnessNumerator'] + a) / (reviews['HelpfulnessDenominator'] + a + b)
t = 1 + np.log1p(reviews['HelpfulnessDenominator'])
reviews['weight_smooth'] = r * t

# 护栏：避免极端权重
reviews['weight_smooth'] = reviews['weight_smooth'].clip(lower=0.05, upper=10)

# %%
# 主聚合
reviews['wscore_simple'] = reviews['Score'] * reviews['weight_simple']
reviews['wscore_smooth'] = reviews['Score'] * reviews['weight_smooth']

agg_main = (reviews
    .groupby('ProductId', as_index=False)
    .agg(
        mean_score=('Score', 'mean'),                 # 等权均分（原 raw/naive）
        num_reviews=('Score', 'size'),
        # simple 权重汇总
        sum_weight_simple=('weight_simple', 'sum'),
        sum_wscore_simple=('wscore_simple', 'sum'),
        # smooth 权重汇总
        sum_weight_smooth=('weight_smooth', 'sum'),
        sum_wscore_smooth=('wscore_smooth', 'sum'),
    )
)

# 1) 计算加权均分（防 0 分母）
agg_main['weighted_mean_simple'] = np.where(
    agg_main['sum_weight_simple'] > 0,
    agg_main['sum_wscore_simple'] / agg_main['sum_weight_simple'],
    np.nan
)
agg_main['weighted_mean_smooth'] = np.where(
    agg_main['sum_weight_smooth'] > 0,
    agg_main['sum_wscore_smooth'] / agg_main['sum_weight_smooth'],
    np.nan
)

# 2) 贝叶斯修正（给 m 设置下限，防 0/NaN）
global_mean = reviews['Score'].mean()
m = agg_main['sum_weight_smooth'].median()
m = np.nan_to_num(m, nan=0.0)
m = max(m, 1e-6)

agg_main['bayesian_mean_smooth'] = (
    (m * global_mean + agg_main['weighted_mean_smooth'] * agg_main['sum_weight_smooth']) /
    (m + agg_main['sum_weight_smooth'])
)

m_simple = agg_main['sum_weight_simple'].median()
m_simple = np.nan_to_num(m_simple, nan=0.0)
m_simple = max(m_simple, 1e-6)

agg_main['bayesian_mean_simple'] = (
    (m_simple * global_mean + agg_main['weighted_mean_simple'] * agg_main['sum_weight_simple']) /
    (m_simple + agg_main['sum_weight_simple'])
)

# 3) 组装得分表（不再从 reviews 透视星级分布）
score_table = agg_main[['ProductId','mean_score','num_reviews',
                        'weighted_mean_simple','weighted_mean_smooth',
                        'bayesian_mean_smooth','bayesian_mean_simple']]

# 4) 合并进产品信息（键对齐 + 清理）
# 统一键类型，避免 dtype 不一致导致合并失败
try:
    df_amazon_product_info['product_id'] = df_amazon_product_info['product_id'].astype(str)
except Exception:
    pass
try:
    score_table['ProductId'] = score_table['ProductId'].astype(str)
except Exception:
    pass
# 避免左表已有同名度量列产生后缀，先移除之
_metric_cols = ['mean_score','num_reviews','weighted_mean_simple','weighted_mean_smooth',
                'bayesian_mean_smooth','bayesian_mean_simple']
df_amazon_product_info = df_amazon_product_info.drop(columns=[c for c in _metric_cols if c in df_amazon_product_info.columns], errors='ignore')

df_amazon_product_info = df_amazon_product_info.merge(
    score_table, left_on='product_id', right_on='ProductId', how='left'
)
df_amazon_product_info = df_amazon_product_info.drop(columns=['ProductId'], errors='ignore')

# 5) 使用现有 ScoreDistribution 生成星级计数列
from ast import literal_eval

def _parse_score_distribution(x):
    # 先处理可迭代容器，避免 pd.isna(list) 返回布尔数组导致歧义
    if isinstance(x, (list, tuple, np.ndarray)):
        return list(x)
    # 处理空字符串/None
    if x is None:
        return [0, 0, 0, 0, 0]
    if isinstance(x, str):
        s = x.strip()
        if not s:
            return [0, 0, 0, 0, 0]
        try:
            return list(literal_eval(s))
        except Exception:
            return [0, 0, 0, 0, 0]
    # 标量的 NaN
    try:
        if pd.isna(x):
            return [0, 0, 0, 0, 0]
    except Exception:
        pass
    return [0, 0, 0, 0, 0]

_sd = df_amazon_product_info['ScoreDistribution'].apply(_parse_score_distribution).apply(pd.Series)
_sd.columns = ['count_1star','count_2star','count_3star','count_4star','count_5star']
for c in _sd.columns:
    df_amazon_product_info[c] = pd.to_numeric(_sd[c], errors='coerce').fillna(0).astype(int)

# 6) 数值列清洗与差异列
for c in ['mean_score','weighted_mean_simple','weighted_mean_smooth','bayesian_mean_smooth','bayesian_mean_simple']:
    if c in df_amazon_product_info.columns:
        df_amazon_product_info[c] = pd.to_numeric(df_amazon_product_info[c], errors='coerce')

df_amazon_product_info['diff_smooth_vs_simple'] = (
    df_amazon_product_info['weighted_mean_smooth'] - df_amazon_product_info['weighted_mean_simple']
)
df_amazon_product_info['diff_bayes_vs_mean'] = (
    df_amazon_product_info['bayesian_mean_smooth'] - df_amazon_product_info['mean_score']
)

# 7) 展示：拆分为三张表
score_cols = ['product_id','num_reviews','mean_score',
              'weighted_mean_simple','weighted_mean_smooth','bayesian_mean_smooth']
diff_cols  = ['product_id','diff_smooth_vs_simple','diff_bayes_vs_mean']
count_cols = ['product_id','count_1star','count_2star','count_3star','count_4star','count_5star']

score_table_view = df_amazon_product_info[score_cols].head(10)
diff_table_view  = df_amazon_product_info[diff_cols].head(10)
count_table_view = df_amazon_product_info[count_cols].head(10)

display(score_table_view)
display(diff_table_view)
display(count_table_view)

# 为后续单元的兼容性保留原 cols_show（如果后续还在用）
cols_show = score_cols + diff_cols[1:] + count_cols[1:]
# Out:
# /var/folders/n9/zfgx5wd52lxcxmk5fxh314t40000gn/T/ipykernel_80691/3136999990.py:63: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   score_table['ProductId'] = score_table['ProductId'].astype(str)
#    product_id  num_reviews  mean_score  weighted_mean_simple  \
# 0  B0007GFDP4          5.0    3.800000              4.000000
# 1  B000EMEEHE         10.0    3.400000              3.583333
# 2  B000E671W0          9.0    4.888889              4.666667
# 3  B000084E76          8.0    2.875000              2.893617
# 4  B0009TQC90          9.0    3.444444              3.666667
# 5  B000FPGYTQ         14.0    4.500000              4.533333
# 6  B0000CDBRK          9.0    4.888889              4.916667
# 7  B000FOYMIC         10.0    3.600000              2.600000
# 8  B0002IF5CI          9.0    3.888889              3.500000
# 9  B0000D9MT1          9.0    3.888889              3.666667
#
#    weighted_mean_smooth  bayesian_mean_smooth  diff_smooth_vs_simple  \
# 0              5.000000              4.396717               1.000000
# 1              3.139252              3.626380              -0.444082
# 2              5.000000              4.396717               0.333333
# 3              2.000000              3.284147              -0.893617
# 4              5.000000              4.396717               1.333333
# 5              3.605579              3.769622              -0.927754
# 6              5.000000              4.666217               0.083333
# 7              3.000000              3.736894               0.400000
# 8              5.000000              4.685869               1.500000
# 9              5.000000              4.537066               1.333333
#
#    diff_bayes_vs_mean  count_1star  count_2star  count_3star  count_4star  \
# 0            0.596717           20            0           19            0
# 1            0.226380           23            9           27            9
# 2           -0.492171            2            1            2            7
# 3            0.409147           26           12           12           13
# 4            0.952273           10           20           32           10
# 5           -0.730378            0            0            3            7
# 6           -0.222672            1            0            2            7
# 7            0.136894           15            7           17           11
# 8            0.796980           13           42           14           14
# 9            0.648177            8            8           10            9
#
#    count_5star
# 0           61
# 1           32
# 2           88
# 3           37
# 4           28
# 5           90
# 6           90
# 7           50
# 8           17
# 9           65

# %%
# 可视化
req_cols = ['num_reviews','mean_score','weighted_mean_smooth','bayesian_mean_smooth']
sample_base = df_amazon_product_info.dropna(subset=[c for c in req_cols if c in df_amazon_product_info.columns])
sample = (sample_base
          .query('num_reviews>=5')
          .sample(min(300, len(sample_base)), random_state=42) if len(sample_base) > 0 else sample_base)

plt.figure(figsize=(6,4))
plt.scatter(sample['num_reviews'], sample['mean_score'], label='mean', alpha=0.5)
plt.scatter(sample['num_reviews'], sample['weighted_mean_smooth'], label='weighted_smooth', alpha=0.5)
plt.scatter(sample['num_reviews'], sample['bayesian_mean_smooth'], label='bayesian_smooth', alpha=0.8)
plt.xlabel('num_reviews'); plt.ylabel('score'); plt.legend(); plt.title('Score vs. Reviews')
plt.ylim(1,5)
plt.show()

# 两个示例
one_review = df_amazon_product_info.query('num_reviews==1').head(1)
# 改为按 weighted_mean_smooth 排序（已存在）；若不存在则退化为 num_reviews
sort_key = 'weighted_mean_smooth' if 'weighted_mean_smooth' in df_amazon_product_info.columns else 'num_reviews'
many_reviews = (df_amazon_product_info.query('num_reviews>=20')
                .sort_values(sort_key, ascending=False)
                .head(1))
display(one_review[cols_show[:6]])
display(many_reviews[cols_show[:6]])
# Out:
#     product_id  num_reviews  mean_score  weighted_mean_simple  \
# 47  B00068R7W0          1.0         1.0                   1.0
#
#     weighted_mean_smooth  bayesian_mean_smooth
# 47                   1.0              3.359143
#     product_id  num_reviews  mean_score  weighted_mean_simple  \
# 49  B000EVIDUY         22.0    4.545455               4.72973
#
#     weighted_mean_smooth  bayesian_mean_smooth
# 49                   5.0              4.909562

# %% [markdown]
# ## 4. Correlation Between Ratings and Product Descriptions
#
# ### 4.1 Correlation with the number of sample images

# %%
# Compute Spearman's correlation coefficient
tmp = df_amazon_product_info[['Score', 'CountAltImages']].dropna()
corr, p_value = spearmanr(tmp["Score"], tmp["CountAltImages"])

print(f"Spearman correlation coefficient: {corr:.4f}; P value: {p_value:.1e}")

df = df_amazon_product_info[df_amazon_product_info.NumRatings > 10].groupby("CountAltImages").agg(
    good_score_percent=("Score", lambda x: (x > 4.5).mean()), n_samples=("Score", "count"))
ax = df.plot(y='n_samples', kind="bar", color="skyblue", width=0.6, figsize=(8, 5),
             title="Good (score > 4.5) percent with number of sample images", xlabel="Number of sample images")
df.plot(y=['good_score_percent'], ax=ax.twinx())
# Out:
# Spearman correlation coefficient: 0.2966; P value: 2.2e-59
# <Axes: xlabel='CountAltImages'>

# %%
df_amazon_food_reviews.pivot_table(index=['UserId'], values=['ProductId'], aggfunc='count').sort_values(
    "ProductId", ascending=False)
# Out:
#                 ProductId
# UserId
# A281NPSIMI1C2R         17
# A1YUL9PCJR3JTY         16
# A3OXHLG6DIBRW8         10
# AXO4PQU0XG3TG           7
# AQQLWCMRNDFGI           7
# ...                   ...
# A2APZJZT4OAKBY          1
# A2AQWKT6IZCXZ3          1
# A2ARKTFI3SE722          1
# A2ARTDAE0C52E4          1
# AZZVNIMTTMJH6           1
#
# [9698 rows x 1 columns]

# %%
p = df_amazon_food_reviews.pivot_table(index=['ProductId'], aggfunc='count')[["Summary"]]
p[p.Summary > 1]
# Out:
#             Summary
# ProductId
# 6641040           3
# 7310172001       19
# 7310172101       16
# B00002N8SM        3
# B00004CI84       23
# ...             ...
# B000GZY8FC        4
# B000GZY8W0        2
# B000GZY942        2
# B000GZY9HY        2
# B000GZYAN2        9
#
# [1845 rows x 1 columns]

# %%
df_amazon_product_info = df_amazon_product_info[
    df_amazon_product_info.category.apply(lambda x: sum(['food' in e.lower() for e in x])) > 0]

# %%
df_amazon_product_info[df_amazon_product_info.NumRatings > 20].plot.scatter(x='Score', y='ScorePolarizationIndex',
                                                                            alpha=0.03)
# Out:
# <Axes: xlabel='Score', ylabel='ScorePolarizationIndex'>

# %%
df_amazon_product_info[df_amazon_product_info.NumRatings > 20].Score.hist(bins=10)
# Out:
# <Axes: >
